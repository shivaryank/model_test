# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
data = pd.read_csv('C:/Users/shiv.kumar/Downloads/train.csv')

# %%
data.head()
# Out:
#    id  Age     BusinessTravel  DailyRate              Department  \
# 0   0   36  Travel_Frequently        599  Research & Development
# 1   1   35      Travel_Rarely        921                   Sales
# 2   2   32      Travel_Rarely        718                   Sales
# 3   3   38      Travel_Rarely       1488  Research & Development
# 4   4   50      Travel_Rarely       1017  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                24          3        Medical              1
# 1                 8          3          Other              1
# 2                26          3      Marketing              1
# 3                 2          3        Medical              1
# 4                 5          4        Medical              1
#
#    EnvironmentSatisfaction  ... StandardHours  StockOptionLevel  \
# 0                        4  ...            80                 1
# 1                        1  ...            80                 1
# ...

# %%
data.shape
# Out:
# (1677, 35)

# %%
# Set the style of the plots
sns.set(style="ticks")
# EDA with Seaborn
# Plot the count of attrition
sns.countplot(x='Attrition', data=data)
plt.title('Attrition Count')
plt.show()

# %%
# Plot the distribution of age
sns.histplot(x='Age', data=data, kde=True)
plt.title('Age Distribution')
plt.show()

# %%
# Plot the attrition by department
sns.countplot(x='Department', hue='Attrition', data=data)
plt.title('Attrition by Department')
plt.show()

# %%
# Plot the attrition by monthly income
sns.boxplot(x='Attrition', y='MonthlyIncome', data=data)
plt.title('Attrition by Monthly Income')
plt.show()

# %%
# Plot the correlation matrix
plt.figure(figsize=(12, 8))
correlation = data.corr()
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
data = pd.read_csv('C:/Users/shiv.kumar/Downloads/test.csv')

# Set the style of the plots
sns.set(style="ticks")

# EDA with Seaborn
# Plot the count of attrition
sns.countplot(x='Attrition', data=data)
plt.title('Attrition Count')
plt.show()

# Plot the distribution of age
sns.histplot(x='Age', data=data, kde=True)
plt.title('Age Distribution')
plt.show()

# Plot the attrition by department
sns.countplot(x='Department', hue='Attrition', data=data)
plt.title('Attrition by Department')
plt.show()

# Plot the attrition by education field
sns.countplot(x='EducationField', hue='Attrition', data=data)
plt.title('Attrition by Education Field')
plt.xticks(rotation=45)
plt.show()

# Plot the attrition by job role
plt.figure(figsize=(12, 6))
sns.countplot(x='JobRole', hue='Attrition', data=data)
plt.title('Attrition by Job Role')
plt.xticks(rotation=45)
plt.show()

# Plot the attrition by job satisfaction
sns.countplot(x='JobSatisfaction', hue='Attrition', data=data)
plt.title('Attrition by Job Satisfaction')
plt.show()

# Plot the attrition by gender
sns.countplot(x='Gender', hue='Attrition', data=data)
plt.title('Attrition by Gender')
plt.show()

# Plot the attrition by monthly income
sns.boxplot(x='Attrition', y='MonthlyIncome', data=data)
plt.title('Attrition by Monthly Income')
plt.show()

# Plot the correlation matrix
plt.figure(figsize=(12, 8))
correlation = data.corr()
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
# Set the style of the plots
sns.set(style="ticks")

# Create subplots for better visualization
fig, axes = plt.subplots(3, 2, figsize=(12, 12))
fig.subplots_adjust(hspace=0.4, wspace=0.3)

# Plot 1: Attrition Count
sns.countplot(x='Attrition', data=data, ax=axes[0, 0])
axes[0, 0].set_title('Attrition Count')
axes[0, 0].set_xlabel('Attrition')
axes[0, 0].set_ylabel('Count')

# Plot 2: Age Distribution
sns.histplot(x='Age', data=data, kde=True, ax=axes[0, 1])
axes[0, 1].set_title('Age Distribution')
axes[0, 1].set_xlabel('Age')
axes[0, 1].set_ylabel('Count')

# Plot 3: Attrition by Department
sns.countplot(x='Department', hue='Attrition', data=data, ax=axes[1, 0])
axes[1, 0].set_title('Attrition by Department')
axes[1, 0].set_xlabel('Department')
axes[1, 0].set_ylabel('Count')
axes[1, 0].legend(title='Attrition', loc='upper right')

# Plot 4: Attrition by Education Field
sns.countplot(x='EducationField', hue='Attrition', data=data, ax=axes[1, 1])
axes[1, 1].set_title('Attrition by Education Field')
axes[1, 1].set_xlabel('Education Field')
axes[1, 1].set_ylabel('Count')
axes[1, 1].legend(title='Attrition', loc='upper right')
axes[1, 1].set_xticklabels(axes[1, 1].get_xticklabels(), rotation=45, ha='right')

# Plot 5: Attrition by Job Role
sns.countplot(x='JobRole', hue='Attrition', data=data, ax=axes[2, 0])
axes[2, 0].set_title('Attrition by Job Role')
axes[2, 0].set_xlabel('Job Role')
axes[2, 0].set_ylabel('Count')
axes[2, 0].legend(title='Attrition', loc='upper right')
axes[2, 0].set_xticklabels(axes[2, 0].get_xticklabels(), rotation=45, ha='right')

# Plot 6: Attrition by Job Satisfaction
sns.countplot(x='JobSatisfaction', hue='Attrition', data=data, ax=axes[2, 1])
axes[2, 1].set_title('Attrition by Job Satisfaction')
axes[2, 1].set_xlabel('Job Satisfaction')
axes[2, 1].set_ylabel('Count')
axes[2, 1].legend(title='Attrition', loc='upper right')

# Plot 4: Attrition by Education Field
sns.countplot(x='EducationField', hue='Attrition', data=data, ax=axes[1, 1])
axes[1, 1].set_title('Attrition by Education Field')
axes[1, 1].set_xlabel('Education Field')
axes[1, 1].set_ylabel('Count')
axes[1, 1].legend(title='Attrition', loc='upper right')
axes[1, 1].set_xticklabels(axes[1, 1].get_xticklabels(), rotation=45, ha='right')

# Plot 5: Attrition by Job Role
sns.countplot(x='JobRole', hue='Attrition', data=data, ax=axes[2, 0])
axes[2, 0].set_title('Attrition by Job Role')
axes[2, 0].set_xlabel('Job Role')
axes[2, 0].set_ylabel('Count')
axes[2, 0].legend(title='Attrition', loc='upper right')
axes[2, 0].set_xticklabels(axes[2, 0].get_xticklabels(), rotation=45, ha='right')

# Plot 6: Attrition by Job Satisfaction
sns.countplot(x='JobSatisfaction', hue='Attrition', data=data, ax=axes[2, 1])
axes[2, 1].set_title('Attrition by Job Satisfaction')
axes[2, 1].set_xlabel('Job Satisfaction')
axes[2, 1].set_ylabel('Count')
axes[2, 1].legend(title='Attrition', loc='upper right')

# Remove empty subplot
fig.delaxes(axes[2, 1])

# Adjust layout to accommodate all subplots
fig.tight_layout()

# Plot 7: Correlation Matrix (Most correlated features)
plt.figure(figsize=(10, 8))
correlation = data.corr()
top_features = correlation['Attrition'].sort_values(ascending=False)[:10].index
sns.heatmap(data[top_features].corr(), annot=True, cmap='coolwarm', ax=plt.gca(), fmt=".2f", annot_kws={"fontsize": 8})
plt.title('Top Correlated Features')
plt.xticks(rotation=45, ha='right', fontsize=8)
plt.yticks(fontsize=8)

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
data = pd.read_csv('employee_attrition.csv')

# Set the style of the plots
sns.set(style="ticks")

# Create subplots for better visualization
fig, axes = plt.subplots(3, 2, figsize=(12, 12))
fig.subplots_adjust(hspace=0.4, wspace=0.3)

# Plot 1: Attrition Count
sns.countplot(x='Attrition', data=data, ax=axes[0, 0])
axes[0, 0].set_title('Attrition Count')
axes[0, 0].set_xlabel('Attrition')
axes[0, 0].set_ylabel('Count')

# Plot 2: Age Distribution
sns.histplot(x='Age', data=data, kde=True, ax=axes[0, 1])
axes[0, 1].set_title('Age Distribution')
axes[0, 1].set_xlabel('Age')
axes[0, 1].set_ylabel('Count')

# Plot 3: Attrition by Department
sns.countplot(x='Department', hue='Attrition', data=data, ax=axes[1, 0])
axes[1, 0].set_title('Attrition by Department')
axes[1, 0].set_xlabel('Department')
axes[1, 0].set_ylabel('Count')
axes[1, 0].legend(title='Attrition', loc='upper right')

# Plot 4: Attrition by Education Field
sns.countplot(x='EducationField', hue='Attrition', data=data, ax=axes[1, 1])
axes[1, 1].set_title('Attrition by Education Field')
axes[1, 1].set_xlabel('Education Field')
axes[1, 1].set_ylabel('Count')
axes[1, 1].legend(title='Attrition', loc='upper right')
axes[1, 1].set_xticklabels(axes[1, 1].get_xticklabels(), rotation=45, ha='right')

# Plot 5: Attrition by Job Role
sns.countplot(x='JobRole', hue='Attrition', data=data, ax=axes[2, 0])
axes[2, 0].set_title('Attrition by Job Role')
axes[2, 0].set_xlabel('Job Role')
axes[2, 0].set_ylabel('Count')
axes[2, 0].legend(title='Attrition', loc='upper right')
axes[2, 0].set_xticklabels(axes[2, 0].get_xticklabels(), rotation=45, ha='right')

# Plot 6: Attrition by Job Satisfaction
sns.countplot(x='JobSatisfaction', hue='Attrition', data=data, ax=axes[2, 1])
axes[2, 1].set_title('Attrition by Job Satisfaction')
axes[2, 1].set_xlabel('Job Satisfaction')
axes[2, 1].set_ylabel('Count')
axes[2, 1].legend(title='Attrition', loc='upper right')

# Plot 4: Attrition by Education Field
sns.countplot(x='EducationField', hue='Attrition', data=data, ax=axes[1, 1])
axes[1, 1].set_title('Attrition by Education Field')
axes[1, 1].set_xlabel('Education Field')
axes[1, 1].set_ylabel('Count')
axes[1, 1].legend(title='Attrition', loc='upper right')
axes[1, 1].set_xticklabels(axes[1, 1].get_xticklabels(), rotation=45, ha='right')

# Plot 5: Attrition by Job Role
sns.countplot(x='JobRole', hue='Attrition', data=data, ax=axes[2, 0])
axes[2, 0].set_title('Attrition by Job Role')
axes[2, 0].set_xlabel('Job Role')
axes[2, 0].set_ylabel('Count')
axes[2, 0].legend(title='Attrition', loc='upper right')
axes[2, 0].set_xticklabels(axes[2, 0].get_xticklabels(), rotation=45, ha='right')

# Plot 6: Attrition by Job Satisfaction
sns.countplot(x='JobSatisfaction', hue='Attrition', data=data, ax=axes[2, 1])
axes[2, 1].set_title('Attrition by Job Satisfaction')
axes[2, 1].set_xlabel('Job Satisfaction')
axes[2, 1].set_ylabel('Count')
axes[2, 1].legend(title='Attrition', loc='upper right')

# Remove empty subplot
fig.delaxes(axes[2, 1])

# Adjust layout to accommodate all subplots
fig.tight_layout()

# Plot 7: Correlation Matrix (Most correlated features)
plt.figure(figsize=(10, 8))
correlation = data.corr()
top_features = correlation['Attrition'].sort_values(ascending=False)[:10].index
sns.heatmap(data[top_features].corr(), annot=True, cmap='coolwarm', ax=plt.gca(), fmt=".2f", annot_kws={"fontsize": 8})
plt.title('Top Correlated Features')
plt.xticks(rotation=45, ha='right', fontsize=8)
plt.yticks(fontsize=8)

plt.show()

# %%
# Set the style of the plots
sns.set(style="ticks")

# Create subplots for better visualization
fig, axes = plt.subplots(3, 2, figsize=(12, 12))
fig.subplots_adjust(hspace=0.4, wspace=0.3)

# Plot 1: Attrition Count
sns.countplot(x='Attrition', data=data, ax=axes[0, 0])
axes[0, 0].set_title('Attrition Count')
axes[0, 0].set_xlabel('Attrition')
axes[0, 0].set_ylabel('Count')

# Plot 2: Age Distribution
sns.histplot(x='Age', data=data, kde=True, ax=axes[0, 1])
axes[0, 1].set_title('Age Distribution')
axes[0, 1].set_xlabel('Age')
axes[0, 1].set_ylabel('Count')

# Plot 3: Attrition by Department
sns.countplot(x='Department', hue='Attrition', data=data, ax=axes[1, 0])
axes[1, 0].set_title('Attrition by Department')
axes[1, 0].set_xlabel('Department')
axes[1, 0].set_ylabel('Count')
axes[1, 0].legend(title='Attrition', loc='upper right')

# Plot 4: Attrition by Education Field
sns.countplot(x='EducationField', hue='Attrition', data=data, ax=axes[1, 1])
axes[1, 1].set_title('Attrition by Education Field')
axes[1, 1].set_xlabel('Education Field')
axes[1, 1].set_ylabel('Count')
axes[1, 1].legend(title='Attrition', loc='upper right')
axes[1, 1].set_xticklabels(axes[1, 1].get_xticklabels(), rotation=45, ha='right')

# Plot 5: Attrition by Job Role
sns.countplot(x='JobRole', hue='Attrition', data=data, ax=axes[2, 0])
axes[2, 0].set_title('Attrition by Job Role')
axes[2, 0].set_xlabel('Job Role')
axes[2, 0].set_ylabel('Count')
axes[2, 0].legend(title='Attrition', loc='upper right')
axes[2, 0].set_xticklabels(axes[2, 0].get_xticklabels(), rotation=45, ha='right')

# Remove empty subplot
fig.delaxes(axes[2, 1])

# Adjust layout to accommodate all subplots
fig.tight_layout()

# Plot 6: Correlation Matrix (Most correlated features)
plt.figure(figsize=(10, 8))
correlation = data.corr()
top_features = correlation['Attrition'].sort_values(ascending=False)[:10].index
sns.heatmap(data[top_features].corr(), annot=True, cmap='coolwarm', ax=plt.gca(), fmt=".2f", annot_kws={"fontsize": 8})
plt.title('Top Correlated Features')
plt.xticks(rotation=45, ha='right', fontsize=8)
plt.yticks(fontsize=8)

# Create subplots for additional correlated features
fig2, axes2 = plt.subplots(2, 2, figsize=(10, 8))
fig2.subplots_adjust(hspace=0.4, wspace=0.3)

# Plot 7: Attrition by Job Level
sns.countplot(x='JobLevel', hue='Attrition', data=data, ax=axes2[0, 0])
axes2[0, 0].set_title('Attrition by Job Level')
axes2[0, 0].set_xlabel('Job Level')
axes2[0, 0].set_ylabel('Count')
axes2[0, 0].legend(title='Attrition', loc='upper right')

# Plot 8: Attrition by YearsAtCompany
sns.boxplot(x='Attrition', y='YearsAtCompany', data=data, ax=axes2[0, 1])
axes2[0, 1].set_title('Attrition by Years at Company')
axes2[0, 1].set_xlabel('Attrition')
axes2[0, 1].set_ylabel('Years at Company')

# Plot 9: Attrition by Relationship Satisfaction
sns.countplot(x='RelationshipSatisfaction', hue='Attrition', data=data, ax=axes2[1, 0])
axes2[1, 0].set_title('Attrition by Relationship Satisfaction')
axes2[1, 0].set_xlabel('Relationship Satisfaction')
axes2[1, 0].set_ylabel('Count')
axes2[1, 0].legend(title='Attrition', loc='upper right')

# Remove empty subplot
fig2.delaxes(axes2[1, 1])

# Adjust layout to accommodate all subplots
fig2.tight_layout()

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
data = pd.read_csv('employee_attrition.csv')

# Set the style of the plots
sns.set(style="ticks")

# Create subplots for better visualization
fig, axes = plt.subplots(3, 2, figsize=(12, 12))
fig.subplots_adjust(hspace=0.4, wspace=0.3)

# Plot 1: Attrition Count
sns.countplot(x='Attrition', data=data, ax=axes[0, 0])
axes[0, 0].set_title('Attrition Count')
axes[0, 0].set_xlabel('Attrition')
axes[0, 0].set_ylabel('Count')

# Plot 2: Age Distribution
sns.histplot(x='Age', data=data, kde=True, ax=axes[0, 1])
axes[0, 1].set_title('Age Distribution')
axes[0, 1].set_xlabel('Age')
axes[0, 1].set_ylabel('Count')

# Plot 3: Attrition by Department
sns.countplot(x='Department', hue='Attrition', data=data, ax=axes[1, 0])
axes[1, 0].set_title('Attrition by Department')
axes[1, 0].set_xlabel('Department')
axes[1, 0].set_ylabel('Count')
axes[1, 0].legend(title='Attrition', loc='upper right')

# Plot 4: Attrition by Education Field
sns.countplot(x='EducationField', hue='Attrition', data=data, ax=axes[1, 1])
axes[1, 1].set_title('Attrition by Education Field')
axes[1, 1].set_xlabel('Education Field')
axes[1, 1].set_ylabel('Count')
axes[1, 1].legend(title='Attrition', loc='upper right')
axes[1, 1].set_xticklabels(axes[1, 1].get_xticklabels(), rotation=45, ha='right')

# Plot 5: Attrition by Job Role
sns.countplot(x='JobRole', hue='Attrition', data=data, ax=axes[2, 0])
axes[2, 0].set_title('Attrition by Job Role')
axes[2, 0].set_xlabel('Job Role')
axes[2, 0].set_ylabel('Count')
axes[2, 0].legend(title='Attrition', loc='upper right')
axes[2, 0].set_xticklabels(axes[2, 0].get_xticklabels(), rotation=45, ha='right')

# Remove empty subplot
fig.delaxes(axes[2, 1])

# Adjust layout to accommodate all subplots
fig.tight_layout()

# Plot 6: Correlation Matrix (Most correlated features)
plt.figure(figsize=(10, 8))
correlation = data.corr()
top_features = correlation['Attrition'].sort_values(ascending=False)[:10].index
sns.heatmap(data[top_features].corr(), annot=True, cmap='coolwarm', ax=plt.gca(), fmt=".2f", annot_kws={"fontsize": 8})
plt.title('Top Correlated Features')
plt.xticks(rotation=45, ha='right', fontsize=8)
plt.yticks(fontsize=8)

# Create subplots for additional correlated features
fig2, axes2 = plt.subplots(2, 2, figsize=(10, 8))
fig2.subplots_adjust(hspace=0.4, wspace=0.3)

# Plot 7: Attrition by Job Level
sns.countplot(x='JobLevel', hue='Attrition', data=data, ax=axes2[0, 0])
axes2[0, 0].set_title('Attrition by Job Level')
axes2[0, 0].set_xlabel('Job Level')
axes2[0, 0].set_ylabel('Count')
axes2[0, 0].legend(title='Attrition', loc='upper right')

# Plot 8: Attrition by YearsAtCompany
sns.boxplot(x='Attrition', y='YearsAtCompany', data=data, ax=axes2[0, 1])
axes2[0, 1].set_title('Attrition by Years at Company')
axes2[0, 1].set_xlabel('Attrition')
axes2[0, 1].set_ylabel('Years at Company')

# Plot 9: Attrition by Relationship Satisfaction
sns.countplot(x='RelationshipSatisfaction', hue='Attrition', data=data, ax=axes2[1, 0])
axes2[1, 0].set_title('Attrition by Relationship Satisfaction')
axes2[1, 0].set_xlabel('Relationship Satisfaction')
axes2[1, 0].set_ylabel('Count')
axes2[1, 0].legend(title='Attrition', loc='upper right')

# Remove empty subplot
fig2.delaxes(axes2[1, 1])

# Adjust layout to accommodate all subplots
fig2.tight_layout()

plt.show()

# %%
# Explore the relationship between the most correlated features and the target variable
fig, axs = plt.subplots(2, 2, figsize=(15,10))
sns.boxplot(x='Attrition', y='JobLevel', data=data, ax=axs[0, 0])
sns.boxplot(x='Attrition', y='YearsWithCurrManager', data=data, ax=axs[0, 1])
sns.boxplot(x='Attrition', y='YearsAtCompany', data=data, ax=axs[1, 0])
sns.boxplot(x='Attrition', y='YearsInCurrentRole', data=data, ax=axs[1, 1])

axs[0, 0].set_title("Job level vs Attrition")
axs[0, 0].set_xlabel("Attrition")
axs[0, 0].set_ylabel("Job level")

axs[0, 1].set_title("Years with current Manager vs Attrition")
axs[0, 1].set_xlabel("Attrition")
axs[0, 1].set_ylabel("Years with current Manager")

axs[1, 0].set_title("Years at Company vs Attrition")
axs[1, 0].set_xlabel("Attrition")
axs[1, 0].set_ylabel("Years at Company")

axs[1, 1].set_title("Years in Current Role vs Attrition")
axs[1, 1].set_xlabel("Attrition")
axs[1, 1].set_ylabel("Years in Current Role")
plt.show()
